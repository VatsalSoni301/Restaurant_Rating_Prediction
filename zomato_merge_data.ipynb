# %%
import numpy as np
import pandas as pd

# %%
# df1=pd.read_csv('./varun/review.csv',header=None)
# df1_bus=pd.read_csv('./varun/restaurant.csv',header=None)
# df1_bus.shape

# %%
df2=pd.read_csv('./darshan2/review.csv',header=None)
df2_bus=pd.read_csv('./darshan2/restaurant.csv',header=None)
df2_bus.shape
# Out:
# (388, 12)

# %%
df3=pd.read_csv('./darshan3/review.csv',header=None)
df3_bus=pd.read_csv('./darshan3/restaurant.csv',header=None)
df3_bus.shape
# Out:
# (399, 12)

# %%
df4=pd.read_csv('./vatsal/review.csv',header=None)
df4_bus=pd.read_csv('./vatsal/restaurant.csv',header=None)
df4_bus.shape
# Out:
# (121, 12)

# %%
df5=pd.read_csv('./dhawal/review.csv',header=None)
df5_bus=pd.read_csv('./dhawal/restaurant.csv',header=None)
df5_bus.shape
df5
# Out:
#              0    1                                                  2  \
# 0     18529208  1.0  We had ordered two chicken dishes via Swiggy. ...
# 1     18529208  1.0  Very poor service, I had ordered Paneer butter...
# 2     18529208  4.0  Food is good and ambience of the place is good...
# 3     18529208  1.0  Not at all satisfied with the quality of food....
# 4     18529208  3.0  Many times i hv ordered from Amigos and have a...
# 5      2500777  4.0  First thing you notice is the ambience!  5/5 f...
# 6      2500777  5.0  One of the best dessert place to go. The choco...
# 7      2500777  4.0  You had your dinner and want to chill out and ...
# 8      2500777  4.0  It's a cosy place for grabbing some light snac...
# 9      2500777  4.0  Good choice of desserts and specially the choc...
# 10     2500030  5.0  Very nice food quality and also nice packing n...
# 11     2500030  5.0  It's a pure vegetarian restaurant serving Raja...
# ...

# %%
list1=[df2,df3,df4,df5]
list1_bus=[df2_bus,df3_bus,df4_bus,df5_bus]

# %%
list1_updated=pd.concat(list1).drop_duplicates().reset_index(drop=True)

# %%
list1_updated.shape
# Out:
# (5169, 7)

# %%
list1_bus_updated=pd.concat(list1_bus).drop_duplicates().reset_index(drop=True)

# %%
list1_bus_updated.shape
# Out:
# (954, 12)

# %%
list1_updated.to_csv("review.csv",index=False)
list1_bus_updated.to_csv("business.csv",index=False)
